# %%
from google.colab import drive
drive.mount('/content/gdrive')
#!ln -s /content/gdrive/My\ Drive/ /mydrive
#!ls /mydrive

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !git clone https://github.com/AlexeyAB/darknet/
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %%
# Enable OpenCV and GPU
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
all_classes = """baglama
"""

file = """text_file = open("build/darknet/x64/data/obj.names", "w");text_file.write(all_classes);text_file.close()""" 

exec(file)
# %pycat build/darknet/x64/data/obj.names

# %%
# Create custom detection class.
obj_data = """classes= 1
train  = build/darknet/x64/data/train.txt
valid  = build/darknet/x64/data/valid.txt
names = build/darknet/x64/data/obj.names
backup = build/darknet/x64/backup/
"""

file = """text_file = open("build/darknet/x64/data/obj.data", "w");text_file.write(obj_data);text_file.close()""" 

exec(file)
# %pycat build/darknet/x64/data/obj.data

# %%
# You can change bounding box coordinate from darknet/src/image_opencv.cpp line 946, after you have to compile darknet using with this cell.
# %cd /content/darknet
# !make

# %%
# !./darknet detector demo build/darknet/x64/data/obj.data '/content/gdrive/MyDrive/yolov3/yolov3_testing.cfg' '/content/gdrive/MyDrive/My Drive/yolov3/yolov3_training_last.weights' -dont_show '/content/gdrive/MyDrive/ColabNotebooks/yolov3/demo_high.mp4' -thresh 0.97 -out_filename baglama_out.mp4

# %%
# Download output if you wish.
from google.colab import files
files.download('baglama_out.mp4')
